# %%
from src.data.loader import conllu_to_df
from src.data.preprocess import multiword_filter, select_4_columns
from IPython.display import display

# %%
df = conllu_to_df('./data/corpus-train.conllu')
df = multiword_filter(df)
df = select_4_columns(df)
display(df.head(20))
# Out:
#                     sent_id  \
# 0   FOLHA_DOC000097_SENT025
# 1   FOLHA_DOC000097_SENT025
# 2   FOLHA_DOC000097_SENT025
# 3   FOLHA_DOC000097_SENT025
# 4   FOLHA_DOC000097_SENT025
# 5   FOLHA_DOC000097_SENT025
# 6   FOLHA_DOC000097_SENT025
# 7   FOLHA_DOC000041_SENT036
# 8   FOLHA_DOC000041_SENT036
# 9   FOLHA_DOC000041_SENT036
# 10  FOLHA_DOC000041_SENT036
# 11  FOLHA_DOC000041_SENT036
# 12  FOLHA_DOC000041_SENT036
# 13  FOLHA_DOC000041_SENT036
# 14  FOLHA_DOC000041_SENT036
# 15  FOLHA_DOC000041_SENT036
# 16  FOLHA_DOC000041_SENT036
# 17  FOLHA_DOC003318_SENT003
# 18  FOLHA_DOC003318_SENT003
# 19  FOLHA_DOC003318_SENT003
#
#                                                  text  id         form  \
# 0                O canal terá o conteúdo reformulado.   1            O
# 1                O canal terá o conteúdo reformulado.   2        canal
# 2                O canal terá o conteúdo reformulado.   3         terá
# 3                O canal terá o conteúdo reformulado.   4            o
# 4                O canal terá o conteúdo reformulado.   5     conteúdo
# 5                O canal terá o conteúdo reformulado.   6  reformulado
# 6                O canal terá o conteúdo reformulado.   7            .
# 7           O homem quando tem filho deixa com a mãe.   1            O
# 8           O homem quando tem filho deixa com a mãe.   2        homem
# 9           O homem quando tem filho deixa com a mãe.   3       quando
# 10          O homem quando tem filho deixa com a mãe.   4          tem
# 11          O homem quando tem filho deixa com a mãe.   5        filho
# 12          O homem quando tem filho deixa com a mãe.   6        deixa
# 13          O homem quando tem filho deixa com a mãe.   7          com
# 14          O homem quando tem filho deixa com a mãe.   8            a
# 15          O homem quando tem filho deixa com a mãe.   9          mãe
# 16          O homem quando tem filho deixa com a mãe.  10            .
# 17  Seu criminoso atávico tinha a testa inclinada,...   1          Seu
# 18  Seu criminoso atávico tinha a testa inclinada,...   2    criminoso
# 19  Seu criminoso atávico tinha a testa inclinada,...   3      atávico
#
#          lemma   upos
# 0            o    DET
# 1        canal   NOUN
# 2          ter   VERB
# 3            o    DET
# 4     conteúdo   NOUN
# 5   reformular   VERB
# 6            .  PUNCT
# 7            o    DET
# 8        homem   NOUN
# 9       quando  SCONJ
# 10         ter   VERB
# 11       filho   NOUN
# 12      deixar   VERB
# 13         com    ADP
# 14           o    DET
# 15         mãe   NOUN
# 16           .  PUNCT
# 17         seu    DET
# 18   criminoso   NOUN
# 19     atávico    ADJ
